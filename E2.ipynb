# %% [markdown]
# ### Yuritza Aros 27/10/2021

# %% [markdown]
# Crear una carpeta nueva en su repositorio git con el nombre E2 (0.2 pto)
# Dentro de E2 crear una carpeta que se llame data. (0.2 pto)
# Guardar los datos asignados en esa carpeta. (0.2 pto)
# Dentro de E2 debera crear un Jupyter Notebook llamado E2. (0.2 pto)
# En el Jupyter Notebook, configurar la primera casilla en Lenguaje Markdown y escribir su nombre, fecha, y esta lista de instrucciones de forma ordenada. (0.2 pts)
# Importar la librería pandas de python para poder procesar y graficar los datos del archivo. Utilizar describe, shape e indicar para que se utilizan estos comandos y que puede deducir de esta información. Debe separar el código en las casillas que estime conveniente, pero se solicita minimo que en una casilla esten solo las importaciones, en otra solo la lectura de los datos y otra con los plots, además cada casilla debe tener una casilla previa que describa el código en formato markdown. (3 pts)
# Hacer los gráficos correspondientes al conjunto de datos seleccionado. (1 pts)
# Utilizar los comandos adecuados de git para actualizar su repositorio y dejarlo disponible en github de forma pública. (1 pts)

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Se crea la variable con el archivo csv

# %%
Covid19= pd.read_csv("data/Covid-19.csv")

# %% [markdown]
# #### muestra la media, la mediana, el maximo y el minimo

# %%
Covid19.describe()
# Out:
#        Codigo region  Codigo comuna      Poblacion  2020-03-30  2020-04-01  \
# count     362.000000     346.000000     346.000000  343.000000  346.000000
# mean        8.784530    9034.997110   56237.890173    5.647230    8.141618
# std         3.884479    3818.147431   88945.967089   19.022787   25.224560
# min         1.000000    1101.000000     137.000000    0.000000    0.000000
# 25%         6.000000    6109.250000    9649.250000    0.000000    0.000000
# 50%         8.000000    8313.500000   19770.000000    0.000000    0.000000
# 75%        13.000000   13102.750000   55441.250000    0.000000    5.000000
# max        16.000000   16305.000000  645909.000000  181.000000  225.000000
#
#        2020-04-03  2020-04-06  2020-04-08  2020-04-10  2020-04-13  ...  \
# count   346.00000  346.000000  346.000000  346.000000  346.000000  ...
# mean     10.15896   13.254335   15.300578   18.138728   21.621387  ...
# std      31.03781   38.455380   42.803249   49.523508   56.388132  ...
# ...

# %% [markdown]
# #### muestra la lista de las columnas en nuestro archivo

# %%
Columnas =list(Covid19.columns)
Columnas
# Out:
# ['Region',
#  'Codigo region',
#  'Comuna',
#  'Codigo comuna',
#  'Poblacion',
#  '2020-03-30',
#  '2020-04-01',
#  '2020-04-03',
#  '2020-04-06',
#  '2020-04-08',
#  '2020-04-10',
#  '2020-04-13',
#  '2020-04-15',
#  '2020-04-17',
#  '2020-04-20',
#  '2020-04-24',
#  '2020-04-27',
#  '2020-05-01',
#  '2020-05-04',
#  '2020-05-08',
#  '2020-05-11',
#  '2020-05-15',
#  '2020-05-18',
#  '2020-05-22',
#  '2020-05-25',
#  '2020-05-29',
#  '2020-06-01',
#  '2020-06-05',
#  '2020-06-08',
#  '2020-06-12',
#  '2020-06-15',
#  '2020-06-19',
#  '2020-06-23',
#  '2020-06-28',
#  '2020-07-01',
#  '2020-07-05',
#  '2020-07-10',
#  '2020-07-13',
#  '2020-07-17',
#  '2020-07-20',
#  '2020-07-24',
#  '2020-07-27',
#  '2020-07-31',
#  '2020-08-03',
#  '2020-08-07',
#  '2020-08-10',
#  '2020-08-14',
#  '2020-08-17',
#  '2020-08-21',
#  '2020-08-24',
#  '2020-08-28',
#  '2020-08-31',
#  '2020-09-04',
#  '2020-09-07',
#  '2020-09-11',
#  '2020-09-14',
#  '2020-09-18',
#  '2020-09-21',
#  '2020-09-25',
# ...

# %% [markdown]
# #### Filtramos los datos de Tasa y Region (se crea una df solo con tasa y region )

# %%
Covid_Filtrado=Covid19[["Region", "Tasa","Comuna"]]
Covid_Filtrado
# Out:
#                  Region     Tasa                          Comuna
# 0    Arica y Parinacota  12170.4                           Arica
# 1    Arica y Parinacota   5677.2                       Camarones
# 2    Arica y Parinacota  10864.2                   General Lagos
# 3    Arica y Parinacota   8389.7                           Putre
# 4    Arica y Parinacota      NaN  Desconocido Arica y Parinacota
# ..                  ...      ...                             ...
# 357          Magallanes   8056.9                       Rio Verde
# 358          Magallanes  10866.4                    San Gregorio
# 359          Magallanes  14893.6                        Timaukel
# 360          Magallanes   2154.8                Torres del Paine
# 361          Magallanes      NaN          Desconocido Magallanes
#
# [362 rows x 3 columns]

# %% [markdown]
# #### Captura solo los valores de la columna region

# %%
Regiones=list (Covid_Filtrado.Region.unique())
Regiones
# Out:
# ['Arica y Parinacota',
#  'Tarapacá',
#  'Antofagasta',
#  'Atacama',
#  'Coquimbo',
#  'Valparaíso',
#  'Metropolitana',
#  'O’Higgins',
#  'Maule',
#  'Ñuble',
#  'Biobío',
#  'Araucanía',
#  'Los Ríos',
#  'Los Lagos',
#  'Aysén',
#  'Magallanes']

# %% [markdown]
# #### Muestra la cantidad de regiones que existen en el archivo

# %%
Covid_Filtrado.Region.nunique()
# Out:
# 16

# %% [markdown]
# #### muestra la cantidad de veces que se repite la misma region

# %%
Covid_Filtrado.Region.value_counts()
# Out:
# Metropolitana         53
# Valparaíso            39
# Biobío                34
# O’Higgins             34
# Araucanía             33
# Los Lagos             31
# Maule                 31
# Ñuble                 22
# Coquimbo              16
# Los Ríos              13
# Magallanes            12
# Aysén                 11
# Atacama               10
# Antofagasta           10
# Tarapacá               8
# Arica y Parinacota     5
# Name: Region, dtype: int64

# %% [markdown]
# #### se graficaran todas las regiones con los datos escogidos

# %%
for region in Regiones:
    Covid=Covid_Filtrado[Covid_Filtrado["Region"]== region]
    Covid=Covid[["Tasa", "Region", "Comuna"]]
    Covid.plot(kind="bar", x="Comuna", y= "Tasa", figsize=(22,10),fontsize=30)
    plt.title("Tasa de Contagios"+ region, fontsize=30)
    plt.xlabel("Comunas", fontsize=25)
    plt.ylabel("Cantidad de  contagios",fontsize=25)
    plt.legend.fontsize=20
    Covid
